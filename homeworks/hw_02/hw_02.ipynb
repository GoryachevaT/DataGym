# %% [markdown]
# # DataGym
# ## Введение в ML, введение в sklearn

# %% [markdown]
# В этом задании мы с вами рассмотрим данные с конкурса [Задача предсказания отклика клиентов ОТП Банка](http://www.machinelearning.ru/wiki/index.php?title=%D0%97%D0%B0%D0%B4%D0%B0%D1%87%D0%B0_%D0%BF%D1%80%D0%B5%D0%B4%D1%81%D0%BA%D0%B0%D0%B7%D0%B0%D0%BD%D0%B8%D1%8F_%D0%BE%D1%82%D0%BA%D0%BB%D0%B8%D0%BA%D0%B0_%D0%BA%D0%BB%D0%B8%D0%B5%D0%BD%D1%82%D0%BE%D0%B2_%D0%9E%D0%A2%D0%9F_%D0%91%D0%B0%D0%BD%D0%BA%D0%B0_%28%D0%BA%D0%BE%D0%BD%D0%BA%D1%83%D1%80%D1%81%29)

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %matplotlib inline

plt.style.use('ggplot')
plt.rcParams['figure.figsize'] = (12,5)

# %% [markdown]
# ### Грузим данные

# %% [markdown]
# Считаем описание данных

# %%
df_descr = pd.read_csv('otp_description.csv', sep='\t', encoding='utf8')

# %%
df_descr
# Out:
#                           ПОЛЕ  \
# 0                 AGREEMENT_RK
# 1                          AGE
# 2            SOCSTATUS_WORK_FL
# 3            SOCSTATUS_PENS_FL
# 4                       GENDER
# 5                  CHILD_TOTAL
# 6                   DEPENDANTS
# 7                    EDUCATION
# 8               MARITAL_STATUS
# 9                 GEN_INDUSTRY
# 10                   GEN_TITLE
# 11                ORG_TP_STATE
# 12             ORG_TP_FCAPITAL
# 13                     JOB_DIR
# 14               FAMILY_INCOME
# 15             PERSONAL_INCOME
# 16        REG_ADDRESS_PROVINCE
# 17       FACT_ADDRESS_PROVINCE
# 18     POSTAL_ADDRESS_PROVINCE
# 19                 TP_PROVINCE
# 20                   REGION_NM
# 21                 REG_FACT_FL
# 22                FACT_POST_FL
# 23                 REG_POST_FL
# 24            REG_FACT_POST_FL
# 25         REG_FACT_POST_TP_FL
# 26              FL_PRESENCE_FL
# 27                    OWN_AUTO
# 28                 AUTO_RUS_FL
# 29              HS_PRESENCE_FL
# 30             COT_PRESENCE_FL
# 31             GAR_PRESENCE_FL
# 32            LAND_PRESENCE_FL
# 33                      CREDIT
# 34                        TERM
# 35                 FST_PAYMENT
# 36              DL_DOCUMENT_FL
# 37             GPF_DOCUMENT_FL
# 38            FACT_LIVING_TERM
# 39                   WORK_TIME
# 40               FACT_PHONE_FL
# 41                REG_PHONE_FL
# 42                GEN_PHONE_FL
# 43              LOAN_NUM_TOTAL
# 44             LOAN_NUM_CLOSED
# 45               LOAN_NUM_PAYM
# 46                LOAN_DLQ_NUM
# 47                LOAN_MAX_DLQ
# 48            LOAN_AVG_DLQ_AMT
# 49            LOAN_MAX_DLQ_AMT
# 50  PREVIOUS_CARD_NUM_UTILIZED
#
#                                              ОПИСАНИЕ
# 0          уникальный идентификатор объекта в выборке
# 1                                     возраст клиента
# 2   социальный статус клиента относительно работы ...
# 3   социальный статус клиента относительно пенсии ...
# 4                 пол клиента (1- женщины, 0-мужчины)
# 5                            количество детей клиента
# 6                       количество иждивенцев клиента
# 7                                         образование
# 8                                  семейное положение
# 9                              отрасль работы клиента
# 10                                          должность
# 11                       форма собственности компании
# 12                  отношение к иностранному капиталу
# 13          направление деятельности в нутри компании
# 14               семейный доход (несколько категорий)
# 15                    личный доход клиента (в рублях)
# 16                        область регистрации клиента
# 17            область фактического пребывания клиента
# 18                             почтовый адрес область
# 19  область торговой точки, где клиент брал послед...
# 20                                          регион РФ
# 21  адрес регистрации и адрес фактического пребыва...
# 22  адрес фактического пребывания клиента и его по...
# 23  адрес регистрации клиента и его почтовый адрес...
# 24  почтовый, фактический и адрес регистрации совп...
# 25  область регистрации, фактического пребывания, ...
# 26  наличие в собственности квартиры (1 - есть, 0 ...
# 27                кол-во автомобилей в собственности
# 28  наличие в собственности автомобиля российского...
# 29  наличие в собственности загородного дома (1 - ...
# 30  наличие в собственности котеджа (1 - есть, 0 -...
# 31  наличие в собственности гаража (1 - есть, 0 - ...
# 32  наличие в собственности земельного участка (1 ...
# 33        сумма последнего кредита клиента (в рублях)
# 34                                       срок кредита
# 35                    первоначальный взнос (в рублях)
# 36  в анкете клиент указал водительское удостовере...
# 37  в анкете клиен указал ГПФ (1 - указал, 0 - не ...
# 38  количество месяцев проживания по месту фактиче...
# 39          время работы на текущем месте (в месяцах)
# 40  наличие в заявке телефона по фактическому мест...
# 41     наличие в заявке телефона по месту регистрации
# 42                 наличие в заявке рабочего телефона
# 43                            количество ссуд клиента
# 44                 количество погашенных ссуд клиента
# 45         количество платежей, которые сделал клиент
# 46          количество просрочек, допущенных клиентом
# 47  номер максимальной просрочки, допущенной клиентом
# 48                 средняя сумма просрочки (в рублях)
# 49            максимальная сумма просрочки (в рублях)
# 50  количество уже утилизированных карт ( если пус...

# %% [markdown]
# Считаем обучающую выборки и тестовую (которую мы как бы не знаем)

# %%
df_train = pd.read_csv('otp_train.csv', sep='\t', encoding='utf8')

# %%
df_train.shape
# Out:
# (15223, 52)

# %%
df_test = pd.read_csv('otp_test.csv', sep='\t', encoding='utf8')

# %%
df_test.shape
# Out:
# (14910, 52)

# %%
df_train.head()
# Out:
#    AGREEMENT_RK  TARGET  AGE  SOCSTATUS_WORK_FL  SOCSTATUS_PENS_FL  GENDER  \
# 0      59910150       0   49                  1                  0       1
# 1      59910230       0   32                  1                  0       1
# 2      59910525       0   52                  1                  0       1
# 3      59910803       0   39                  1                  0       1
# 4      59911781       0   30                  1                  0       0
#
#    CHILD_TOTAL  DEPENDANTS            EDUCATION  MARITAL_STATUS  \
# 0            2           1  Среднее специальное  Состою в браке
# 1            3           3              Среднее  Состою в браке
# 2            4           0     Неполное среднее  Состою в браке
# 3            1           1               Высшее  Состою в браке
# 4            0           0              Среднее  Состою в браке
#
#              ...             REG_PHONE_FL GEN_PHONE_FL LOAN_NUM_TOTAL  \
# 0            ...                        0            1              1
# 1            ...                        0            1              1
# 2            ...                        0            1              2
# 3            ...                        1            1              1
# 4            ...                        0            1              2
#
#   LOAN_NUM_CLOSED LOAN_NUM_PAYM LOAN_DLQ_NUM LOAN_MAX_DLQ  LOAN_AVG_DLQ_AMT  \
# 0               1             6            2            1              1580
# 1               1             6            1            1              4020
# 2               1            11            0            0                 0
# 3               1             6            3            1  1589,92333333333
# 4               1            16            2            1           1152,15
#
#   LOAN_MAX_DLQ_AMT PREVIOUS_CARD_NUM_UTILIZED
# 0             1580                        NaN
# 1             4020                        NaN
# 2                0                        NaN
# 3             1590                        NaN
# 4             2230                        NaN
#
# [5 rows x 52 columns]

# %% [markdown]
# ## Объединим две выборки
#
# Так как пока мы пока не умеем работать sklearn  Pipeline, то для того, чтобы после предобработки столбцы в двух выборках находились на своих местах.
#
# Для того, чтобы в дальнейшем отделить их введем новый столбец "sample"

# %%
df_train['sample'] = 'train'
df_test['sample'] = 'test'

# %%
df = df_test.append(df_train).reset_index(drop=True)

# %%
df.shape
# Out:
# (30133, 53)

# %% [markdown]
# ### Чуть-чуть посмотрим на данные

# %% [markdown]
# Посмотрим типы данных и их заполняемость

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 30133 entries, 0 to 30132
# Data columns (total 53 columns):
# AGREEMENT_RK                  30133 non-null int64
# TARGET                        30133 non-null int64
# AGE                           30133 non-null int64
# SOCSTATUS_WORK_FL             30133 non-null int64
# SOCSTATUS_PENS_FL             30133 non-null int64
# GENDER                        30133 non-null int64
# CHILD_TOTAL                   30133 non-null int64
# DEPENDANTS                    30133 non-null int64
# EDUCATION                     30133 non-null object
# MARITAL_STATUS                30133 non-null object
# GEN_INDUSTRY                  27420 non-null object
# GEN_TITLE                     27420 non-null object
# ORG_TP_STATE                  27420 non-null object
# ORG_TP_FCAPITAL               27425 non-null object
# JOB_DIR                       27420 non-null object
# FAMILY_INCOME                 30133 non-null object
# PERSONAL_INCOME               30133 non-null object
# REG_ADDRESS_PROVINCE          30133 non-null object
# FACT_ADDRESS_PROVINCE         30133 non-null object
# POSTAL_ADDRESS_PROVINCE       30133 non-null object
# TP_PROVINCE                   29543 non-null object
# REGION_NM                     30131 non-null object
# REG_FACT_FL                   30133 non-null int64
# FACT_POST_FL                  30133 non-null int64
# REG_POST_FL                   30133 non-null int64
# REG_FACT_POST_FL              30133 non-null int64
# REG_FACT_POST_TP_FL           30133 non-null int64
# FL_PRESENCE_FL                30133 non-null int64
# OWN_AUTO                      30133 non-null int64
# AUTO_RUS_FL                   30133 non-null int64
# HS_PRESENCE_FL                30133 non-null int64
# COT_PRESENCE_FL               30133 non-null int64
# GAR_PRESENCE_FL               30133 non-null int64
# LAND_PRESENCE_FL              30133 non-null int64
# CREDIT                        30133 non-null object
# TERM                          30133 non-null int64
# FST_PAYMENT                   30133 non-null object
# DL_DOCUMENT_FL                30133 non-null int64
# GPF_DOCUMENT_FL               30133 non-null int64
# FACT_LIVING_TERM              30133 non-null int64
# WORK_TIME                     27416 non-null float64
# FACT_PHONE_FL                 30133 non-null int64
# REG_PHONE_FL                  30133 non-null int64
# GEN_PHONE_FL                  30133 non-null int64
# LOAN_NUM_TOTAL                30133 non-null int64
# LOAN_NUM_CLOSED               30133 non-null int64
# LOAN_NUM_PAYM                 30133 non-null int64
# LOAN_DLQ_NUM                  30133 non-null int64
# LOAN_MAX_DLQ                  30133 non-null int64
# LOAN_AVG_DLQ_AMT              30133 non-null object
# LOAN_MAX_DLQ_AMT              30133 non-null object
# PREVIOUS_CARD_NUM_UTILIZED    600 non-null float64
# sample                        30133 non-null object
# dtypes: float64(2), int64(32), object(19)
# memory usage: 12.2+ MB

# %% [markdown]
# Видим, что часть данных - object, скорее всего стоки.
#
#
# Давайте выведем эти значения для каждого столбца

# %%
for i in df.columns:                      # перебираем все столбцы
    if str(df[i].dtype) == 'object':      # если тип столбца - object
        print('='*10)
        print(i)                                # выводим название столбца
        print(set(df[i]))                 # выводим все его значения (но делаем set - чтоб значения не повторялись)
        print('\n')                             # выводим пустую строку
# Out:
# ==========
# EDUCATION
# {'Высшее', 'Среднее', 'Ученая степень', 'Неоконченное высшее', 'Среднее специальное', 'Неполное среднее', 'Два и более высших образования'}
#
#
# ==========
# MARITAL_STATUS
# {'Не состоял в браке', 'Состою в браке', 'Разведен(а)', 'Гражданский брак', 'Вдовец/Вдова'}
#
#
# ==========
# GEN_INDUSTRY
# {nan, 'Ресторанный бизнес/Общественное питание', 'Недвижимость', 'Здравоохранение', 'Образование', 'Государственная служба', 'Транспорт', 'ЧОП/Детективная д-ть', 'Страхование', 'Наука', 'Юридические услуги/нотариальные услуги', 'Салоны красоты и здоровья', 'СМИ/Реклама/PR-агенства', 'Строительство', 'Информационные технологии', 'Логистика', 'Металлургия/Промышленность/Машиностроение', 'Маркетинг', 'Другие сферы', 'Развлечения/Искусство', 'Управляющая компания', 'Энергетика', 'Химия/Парфюмерия/Фармацевтика', 'Торговля', 'Туризм', 'Коммунальное хоз-во/Дорожные службы', 'Сборочные производства', 'Информационные услуги', 'Банк/Финансы', 'Сельское хозяйство', 'Нефтегазовая промышленность', 'Подбор персонала'}
#
#
# ==========
# GEN_TITLE
# {nan, 'Руководитель высшего звена', 'Военнослужащий по контракту', 'Руководитель среднего звена', 'Руководитель низшего звена', 'Партнер', 'Работник сферы услуг', 'Служащий', 'Другое', 'Индивидуальный предприниматель', 'Рабочий', 'Высококвалифиц. специалист', 'Специалист'}
#
#
# ==========
# ORG_TP_STATE
# {nan, 'Некоммерческая организация', 'Государственная комп./учреж.', 'Индивидуальный предприниматель', 'Частная ком. с инос. капиталом', 'Частная компания'}
#
#
# ==========
# ORG_TP_FCAPITAL
# {nan, 'Без участия', 'С участием'}
#
#
# ==========
# JOB_DIR
# {'Участие в основ. деятельности', nan, 'Пр-техн. обесп. и телеком.', 'Адм-хоз. и трансп. службы', 'Бухгалтерия, финансы, планир.', 'Служба безопасности', 'Снабжение и сбыт', 'Реклама и маркетинг', 'Юридическая служба', 'Вспомогательный техперсонал', 'Кадровая служба и секретариат'}
#
#
# ==========
# FAMILY_INCOME
# {'от 20000 до 50000 руб.', 'свыше 50000 руб.', 'до 5000 руб.', 'от 5000 до 10000 руб.', 'от 10000 до 20000 руб.'}
#
#
# ==========
# PERSONAL_INCOME
# {'5900', '8750', '26800', '7100', '8200', '8350', '11400', '17900', '5300', '13450', '13900', '30000', '4680', '4400', '17404', '17800', '29000', '3300', '21300', '100000', '17600', '10400', '7250', '3500', '4000', '45000', '35500', '92000', '12800', '12400', '11300', '10800', '8900', '7600', '17400', '5280', '15380', '2776', '4250', '22500', '7650', '3600', '12900', '18500', '14200', '11800', '39000', '24', '27200', '33000', '32000', '18600', '5120', '8250', '6600', '19600', '5890', '5173', '13200', '6299,19', '16107,47', '29500', '5000', '12450', '7380', '2800', '12600', '110000', '67700', '15600', '30600', '23100', '11500', '19200', '5339', '3000', '7300', '7330', '5230', '8075', '4590', '5088', '22000', '14700', '14500', '21800', '7700', '9750', '13800', '6400', '17300', '158000', '4500', '14600', '170000', '16100', '15750', '3200', '6608', '11640', '17700', '12650', '3100', '94000', '26500', '5750', '24800
', 'Воронежская область', 'Костромская область', 'Хабаровский край', 'Смоленская область', 'Камчатская область', 'Томская область', 'Амурская область', 'Тамбовская область', 'Московская область', 'Удмуртия', 'Белгородская область', 'Северная Осетия', 'Курская область', 'Якутия', 'Чувашия', 'Агинский Бурятский АО', 'Санкт-Петербург', 'Кировская область', 'Тюменская область', 'Татарстан', 'Читинская область', 'Магаданская область', 'Еврейская АО', 'Свердловская область', 'Горный Алтай', 'Калмыкия', 'Саратовская область', 'Нижегородская область', 'Пермская область', 'Липецкая область', 'Самарская область', 'Башкирия', 'Хакасия', 'Калининградская область', 'Бурятия', 'Адыгея', 'Волгоградская область', 'Архангельская область', 'Псковская область'}
#
#
# ==========
# FACT_ADDRESS_PROVINCE
# {'Ростовская область', 'Рязанская область', 'Калужская область', 'Кабардино-Балкария', 'Орловская область', 'Мурманская область', 'Владимирская область', 'Иркутская область', 'Карачаево-Черкесия', 'Новосибирская область', 'Брянская область', 'Челябинская область', 'Курганская область', 'Вологодская область', 'Ставропольский край', 'Сахалинская область', 'Новгородская область', 'Краснодарский край', 'Пензенская область', 'Оренбургская область', 'Чечня', 'Астраханская область', 'Тульская область', 'Приморский край', 'Красноярский край', 'Марийская республика', 'Карелия', 'Ямало-Ненецкий АО', 'Усть-Ордынский Бурятский АО', 'Кемеровская область', 'Дагестан', 'Ханты-Мансийский АО', 'Омская область', 'Ярославская область', 'Коми', 'Москва', 'Ульяновская область', 'Мордовская республика', 'Коми-Пермяцкий АО', 'Ленинградская область', 'Алтайский край', 'Тверская область', 'Ивановская область', 'Эвенкийский АО', 'Воронежская область', 'Костромская область', 'Хабаровский край', 'Смоленская область', 'Камчатская область', 'Томская область', 'Амурская область', 'Тамбовская область', 'Московская область', 'Удмуртия', 'Белгородская область', 'Северная Осетия', 'Курская область', 'Якутия', 'Чувашия', 'Агинский Бурятский АО', 'Санкт-Петербург', 'Кировская область', 'Тюменская область', 'Татарстан', 'Читинская область', 'Магаданская область', 'Еврейская АО', 'Свердловская область', 'Горный Алтай', 'Калмыкия', 'Саратовская область', 'Нижегородская область', 'Пермская область', 'Липецкая область', 'Самарская область', 'Башкирия', 'Хакасия', 'Калининградская область', 'Бурятия', 'Адыгея', 'Волгоградская область', 'Архангельская область', 'Псковская область'}
#
#
# ==========
# POSTAL_ADDRESS_PROVINCE
# {'Ростовская область', 'Рязанская область', 'Калужская область', 'Кабардино-Балкария', 'Орловская область', 'Мурманская область', 'Владимирская область', 'Иркутская область', 'Карачаево-Черкесия', 'Новосибирская область', 'Брянская область', 'Челябинская область', 'Курганская область', 'Вологодская область', 'Ставропольский край', 'Сахалинская область', 'Новгородская область', 'Краснодарский край', 'Пензенская область', 'Оренбургская область', 'Астраханская область', 'Тульская область', 'Приморский край', 'Красноярский край', 'Марийская республика', 'Карелия', 'Ямало-Ненецкий АО', 'Усть-Ордынский Бурятский АО', 'Кемеровская область', 'Дагестан', 'Ханты-Мансийский АО', 'Омская область', 'Ярославская область', 'Коми', 'Москва', 'Ульяновская область', 'Мордовская республика', 'Коми-Пермяцкий АО', 'Ленинградская область', 'Алтайский край', 'Тверская область', 'Ивановская область', 'Эвенкийский АО', 'Воронежская область', 'Костромская область', 'Хабаровский край', 'Смоленская область', 'Камчатская область', 'Томская область', 'Амурская область', 'Тамбовская область', 'Московская область', 'Удмуртия', 'Белгородская область', 'Северная Осетия', 'Курская область', 'Якутия', 'Чувашия', 'Агинский Бурятский АО', 'Санкт-Петербург', 'Кировская область', 'Тюменская область', 'Татарстан', 'Читинская область', 'Магаданская область', 'Еврейская АО', 'Свердловская область', 'Горный Алтай', 'Калмыкия', 'Саратовская область', 'Нижегородская область', 'Пермская область', 'Липецкая область', 'Самарская область', 'Башкирия', 'Хакасия', 'Калининградская область', 'Бурятия', 'Адыгея', 'Волгоградская область', 'Архангельская область', 'Псковская область'}
#
#
# ==========
# TP_PROVINCE
# {'Ростовская область', nan, 'Рязанская область', 'Оренбургская область', 'Свердловская область', 'Магаданская область', 'Горный Алтай', 'Астраханская область', 'Алтайский край', 'Саратовская область', 'Нижегородская область', 'Тульская область', 'Пермская область', 'Приморский край', 'Липецкая область', 'Красноярский край', 'Ивановская область', 'Орловская область', 'Тверская область', 'Самарская область', 'Калужская область', 'Кабардино-Балкария', 'Мурманская область', 'Башкирия', 'Марийская республика', 'Воронежская область', 'Костромская область', 'Карелия', 'Владимирская область', 'Кемеровская область', 'Татарстан', 'Хабаровский край', 'Калининградская область', 'Ханты-Мансийский АО', 'Омская область', 'Бурятия', 'Иркутская область', 'Новосибирская область', 'Архангельская область', 'Смоленская область', 'Брянская область', 'Ярославская область', 'Новгородская область', 'Коми', 'Камчатская область', 'Томская область', 'Челябинская область', 'Амурская область', 'Тамбовская область', 'Удмуртия', 'Белгородская область', 'Москва', 'Курганская область', 'Курская область', 'Якутия', 'Чувашия', 'Адыгея', 'Вологодская область', 'Ставропольский край', 'Кировская область', 'Волгоградская область', 'Ульяновская область', 'Мордовская республика', 'Читинская область', 'Краснодарский край', 'Тюменская область', 'Санкт-Петербург', 'Еврейская АО', 'Сахалинская область', 'Псковская область', 'Пензенская область'}
#
#
# ==========
# REGION_NM
# {nan, 'ДАЛЬНЕВОСТОЧНЫЙ', 'ЮЖНЫЙ', 'ЦЕНТРАЛЬНЫЙ ОФИС', 'УРАЛЬСКИЙ', 'ЦЕНТРАЛЬНЫЙ 2', 'СЕВЕРО-ЗАПАДНЫЙ', 'ПОВОЛЖСКИЙ', 'ЗАПАДНО-СИБИРСКИЙ', 'ПРИВОЛЖСКИЙ', 'ЦЕНТРАЛЬНЫЙ 1', 'ВОСТОЧНО-СИБИРСКИЙ'}
#
#
# ==========
# CREDIT
# {'12599,9', '4254,12', '14220', '32525', '65241', '16893', '11270', '25350', '7030', '21688', '17451', '63600', '7718', '24195', '5149', '28240', '14091', '7754', '12670', '10338', '44920', '11697', '13900', '8995', '21936', '3892', '40824', '7937', '4839', '6672', '18875', '19071', '13480', '10238,82', '19470', '6567', '19275,91', '12910', '12399', '22685', '13112', '16970', '38340', '12541', '29386', '100000', '23265', '9759', '15895', '42682', '7443', '4153', '23865', '4096', '3270', '15390', '12800', '18840', '8872', '20766', '13370', '16790', '20568', '43573', '11520', '7824', '9928', '7527', '5515,95', '30900', '5581', '12490', '23121', '18135', '49798,
577,92', '2300', '1645,64', '799,09', '1817,76', '1288,7', '3860,18', '1832,91', '472,11', '2500', '800', '2510,2', '869,26', '1154,9', '1177,84', '831,2', '1620', '1160,21', '2770', '4190', '2102,75', '2399,55', '1666,28', '801,8', '790', '1110,39', '1485,15', '1268', '2153,67', '2282,89', '2144,77', '666,41', '1966,99', '956,1', '1154,34', '2158,72', '620,18', '3470', '3390', '1299,55', '2261,19', '1583,15', '5780', '6080', '430', '1170', '14870', '1150', '5420', '2760', '1745,7', '610', '5470', '1770', '2310', '5047,5', '5180', '66 ...
#
#
# ==========
# sample
# {'test', 'train'}

# %% [markdown]
# Mожно заметить что некоторые переменные, которые обозначены как строки (например PERSONAL_INCOME) на самом деле числа, но по какой-то причине были распознаны как строки
#
# Причина же что использовалась запятая для разделения не целой части числа..

# %% [markdown]
# Перекодировать их можно например так:

# %%
df['PERSONAL_INCOME'].map(lambda x: x.replace(',', '.')).astype('float')
# так это исправляется, но результат не записывается никуда)
# Out:
# 0         7000.0
# 1         4100.0
# 2        40000.0
# 3        20000.0
# 4        17000.0
# 5         7000.0
# 6        10000.0
# 7         7500.0
# 8         9000.0
# 9         4000.0
# 10       15000.0
# 11       12000.0
# 12        8000.0
# 13       20000.0
# 14       18500.0
# 15       14000.0
# 16        6000.0
# 17        9000.0
# 18        5000.0
# 19       15000.0
# 20        6100.0
# 21       22180.0
# 22        9000.0
# 23        8700.0
# 24        7000.0
# 25        6000.0
# 26       15000.0
# 27       12000.0
# 28       11000.0
# 29        8000.0
#           ...
# 30103    12000.0
# 30104    10000.0
# 30105    10000.0
# 30106     8000.0
# 30107    11000.0
# 30108     7000.0
# 30109    10000.0
# 30110     8000.0
# 30111    25000.0
# 30112    10000.0
# 30113    12000.0
# 30114     7000.0
# 30115    12000.0
# 30116    14500.0
# 30117    12000.0
# 30118     8000.0
# 30119     7000.0
# 30120    10000.0
# 30121    10000.0
# 30122    10000.0
# 30123    15000.0
# 30124     8100.0
# 30125     9500.0
# 30126    13000.0
# 30127    10000.0
# 30128    12000.0
# 30129    10000.0
# 30130     6000.0
# 30131     4500.0
# 30132    20000.0
# Name: PERSONAL_INCOME, Length: 30133, dtype: float64

# %% [markdown]
# Такой эффект наблюдается в столбцах `PERSONAL_INCOME`, `CREDIT`, `FST_PAYMENT`, `LOAN_AVG_DLQ_AMT`, `LOAN_MAX_DLQ_AMT`

# %% [markdown]
# ### Теперь ваше небольшое исследование

# %% [markdown]
# #### Задание 1. Есть ли пропуски в данных? Заполните их нулями

# %%
df = df.fillna(0)

# %% [markdown]
# #### Задание 2. В данных есть признаки, которые можно назвать категориальным, например семейный статус
#  {'Состою в браке', 'Разведен(а)', 'Не состоял в браке', 'Вдовец/Вдова', 'Гражданский брак'}
#  и таких много
# #### Закодируйте их числами (например идентификаторами 1, 2, 3, ... )
# #### Можно иначе, если есть идеи как.

# %%
cat_col = ['MARITAL_STATUS']

for col in cat_col:
    vals = set(df[col].values)
    dct = dict(zip(vals, range(len(vals))))
    #df['CAT_{}'.format(col)] = df[col].map(dct)

# %% [markdown]
# #### Задание 3. Фунция предобработки

# %% [markdown]
# Напишите функцию, которая бы
#
# * Удаляло идентификатор `AGREEMENT_RK`
# * Избавлялась от проблем с '.' и ',' в стобцах PERSONAL_INCOME, CREDIT, FST_PAYMENT, LOAN_AVG_DLQ_AMT, LOAN_MAX_DLQ_AMT
# * Что-то делала с пропусками (см задание 1)
# * Кодировала категориальные признаки (см задание 2) Если закодировать признаки вам не удалось - удалите все что не числа
#
# В результате, ваш датафрейм должен содержать только числа и не содержать пропусков!

# %%
def preproc_data(df_input):
    df_output = df_input.copy()
    
    df_output.drop('AGREEMENT_RK', axis=1, inplace=True)
    
    # изменение типов данных
    cols_to_change_type = ['PERSONAL_INCOME', 'CREDIT', 'FST_PAYMENT', 'LOAN_AVG_DLQ_AMT', 'LOAN_MAX_DLQ_AMT']
    for col in cols_to_change_type:
        df_output[col] = df_output[col].map(lambda x: x.replace(',', '.')).astype('float')
    
    # заполнение пропусков
    df_output = df.fillna(0)
    
    # кодировка категориальных переменных
    for cat_col in df_output.drop('sample', axis=1).select_dtypes(include='object').columns:
        try:
            vals = set(df_output[cat_col].values)
            dct = dict(zip(vals, range(len(vals))))
            df_output[cat_col] = df_output[cat_col].map(dct)
        except:
            df_output.drop(cat_col, axis=1, inplace=True)
        
    return df_output

# %%
df_preproc = df.pipe(preproc_data) # применит вашу написанную выше функцию к датафрейму и вернут новый

# %%
df_preproc.head()
# Out:
#    AGREEMENT_RK  TARGET  AGE  SOCSTATUS_WORK_FL  SOCSTATUS_PENS_FL  GENDER  \
# 0      59909969       0   30                  1                  0       1
# 1      59910420       0   48                  0                  1       1
# 2      59911223       0   35                  1                  0       0
# 3      59911322       0   22                  1                  0       0
# 4      59911438       0   27                  1                  0       1
#
#    CHILD_TOTAL  DEPENDANTS  EDUCATION  MARITAL_STATUS   ...    GEN_PHONE_FL  \
# 0            1           1          4               0   ...               1
# 1            0           0          1               1   ...               0
# 2            1           0          1               0   ...               1
# 3            0           0          1               0   ...               1
# 4            2           2          0               1   ...               1
#
#    LOAN_NUM_TOTAL  LOAN_NUM_CLOSED  LOAN_NUM_PAYM  LOAN_DLQ_NUM  LOAN_MAX_DLQ  \
# 0               2                2              8             0             0
# 1               2                1             15             0             0
# 2               1                1              1             0             0
# 3               3                2              9             0             0
# 4               1                1              5             0             0
#
#    LOAN_AVG_DLQ_AMT  LOAN_MAX_DLQ_AMT  PREVIOUS_CARD_NUM_UTILIZED  sample
# 0                47                41                         0.0    test
# 1                47                41                         0.0    test
# 2                47                41                         0.0    test
# 3                47                41                         0.0    test
# 4                47                41                         0.0    test
#
# [5 rows x 53 columns]

# %%
df_preproc.select_dtypes(include='object').head()
# Out:
#   sample
# 0   test
# 1   test
# 2   test
# 3   test
# 4   test

# %% [markdown]
# #### Задание 4. Выше мы собрали данные в один датафрейм и записали столбец sample, чтоб было видно где что осталось.
# #### ... напишите код, который разделит df_preproc на 2 части train и test (записав в df_train_preproc и df_test_preproc соответственно)
# #### ... удалив колонку sample

# %%
df_train_preproc = df_preproc[df_preproc['sample']=='train'].drop('sample', axis=1)
df_test_preproc  = df_preproc[df_preproc['sample']=='test'].drop('sample', axis=1)

# %% [markdown]
# #### Задание 5. Отделите целевую переменную и остальные признаки (речь не про train_test_split)
# Выше у вас получились матрицы df_train_preproc и df_test_preproc
#
# Должно получится:
# * 2 матрицы: X и X_valid
# * 2 вектора: y и y_valid
#
#
# * где X - все данные df_train_preproc, кроме TARGET
# * где X_valid - все данные df_test_preproc, кроме TARGET
# * где y - TARGET от df_train_preproc
# * где y_valid - TARGET от df_test_preproc

# %%
X = df_train_preproc.drop('TARGET', axis=1)
y = df_train_preproc['TARGET']

X_valid = df_test_preproc.drop('TARGET', axis=1)
y_valid = df_test_preproc['TARGET']

# %% [markdown]
# #### Задание 6. Обучение и оценка качества разных моделей

# %%
# Поделите данные X и y на 2 части (train и test, размером от исходного 70% и 30% соответственно)

from sklearn.model_selection import train_test_split

X_train, X_test, y_tarin, y_test = train_test_split(X, y, test_size=0.3)

# %%
print('train shape: {}'.format(y_tarin.shape[0]))
print('test  shape: {}'.format(y_test.shape[0]))
# Out:
# train shape: 10656
# test  shape: 4567

# %%
# Попробовать следующие "черные ящики": интерфейс у всех одинаковый 
# Постепенно мы узнаем, что они делаютб а сейчас учимся выбирать какой работает качественнее
#     fit, 
#     predict
# записав предсказания в pred_1, pred_2, pred_3

from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.linear_model import LogisticRegression

tree = DecisionTreeClassifier()
rf   = RandomForestClassifier()
lr   = LogisticRegression()

# %%
tree.fit(X_train, y_tarin)
# Out:
# DecisionTreeClassifier(class_weight=None, criterion='gini', max_depth=None,
#             max_features=None, max_leaf_nodes=None,
#             min_impurity_decrease=0.0, min_impurity_split=None,
#             min_samples_leaf=1, min_samples_split=2,
#             min_weight_fraction_leaf=0.0, presort=False, random_state=None,
#             splitter='best')

# %%
rf.fit(X_train, y_tarin)
# Out:
# /Users/antonina.goryacheva/anaconda3/lib/python3.7/site-packages/sklearn/ensemble/forest.py:246: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# RandomForestClassifier(bootstrap=True, class_weight=None, criterion='gini',
#             max_depth=None, max_features='auto', max_leaf_nodes=None,
#             min_impurity_decrease=0.0, min_impurity_split=None,
#             min_samples_leaf=1, min_samples_split=2,
#             min_weight_fraction_leaf=0.0, n_estimators=10, n_jobs=None,
#             oob_score=False, random_state=None, verbose=0,
#             warm_start=False)

# %%
lr.fit(X_train, y_tarin)
# Out:
# /Users/antonina.goryacheva/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/logistic.py:433: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# LogisticRegression(C=1.0, class_weight=None, dual=False, fit_intercept=True,
#           intercept_scaling=1, max_iter=100, multi_class='warn',
#           n_jobs=None, penalty='l2', random_state=None, solver='warn',
#           tol=0.0001, verbose=0, warm_start=False)

# %%
pred_1 = tree.predict(X_test)
pred_2 = rf.predict(X_test)
pred_3 = lr.predict(X_test)

# %%
# Посчитать метрики стандартные
# accuracy, precision, recall, а1
# в pred_1, pred_2, pred_3 у вас должны лежать предсказания разных "ящиков"
# посчитайте метрики для каждого

from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score

# %%
accuracy_list = [accuracy_score(y_test, pred) for pred in [pred_1, pred_2, pred_3]]
precision_list = [precision_score(y_test, pred) for pred in [pred_1, pred_2, pred_3]]
recall_list = [recall_score(y_test, pred) for pred in [pred_1, pred_2, pred_3]]
f1_list = [f1_score(y_test, pred) for pred in [pred_1, pred_2, pred_3]]
# Out:
# /Users/antonina.goryacheva/anaconda3/lib/python3.7/site-packages/sklearn/metrics/classification.py:1143: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples.
#   'precision', 'predicted', average, warn_for)
# /Users/antonina.goryacheva/anaconda3/lib/python3.7/site-packages/sklearn/metrics/classification.py:1143: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 due to no predicted samples.
#   'precision', 'predicted', average, warn_for)

# %%
accuracy_list
# Out:
# [0.7851981607181957, 0.8789139478870156, 0.8808846069629954]

# %%
precision_list
# Out:
# [0.15698587127158556, 0.2631578947368421, 0.0]

# %%
recall_list
# Out:
# [0.18382352941176472, 0.009191176470588236, 0.0]

# %%
f1_list
# Out:
# [0.1693480101608806, 0.017761989342806393, 0.0]

# %%
# Визуалищировать эти метрики всех моделей на одном графике (чтоб визуально сравнить  качество)
# Возможно вас удивит качество! Но задача подобрана специально ;) Такое качество тоже бывает
plt.figure(figsize=(15, 8))

plt.plot(accuracy_list, label='accuracy', linewidth=2);
plt.plot(precision_list, label='precision', linewidth=2);
plt.plot(recall_list, label='recall', linewidth=2);
plt.plot(f1_list, label='f1', linewidth=2);
plt.legend(loc='upper right', fontsize=12);

# %%
pd.DataFrame([accuracy_list, precision_list, recall_list, f1_list], 
            columns=['Decision Tree', 'Random Forest', 'Logistic Regression'],
            index=['accuracy', 'precision', 'recall', 'f1'])
# Out:
#            Decision Tree  Random Forest  Logistic Regression
# accuracy        0.785198       0.878914             0.880885
# precision       0.156986       0.263158             0.000000
# recall          0.183824       0.009191             0.000000
# f1              0.169348       0.017762             0.000000

# %% [markdown]
# #### Задание 7. Заключительное.
# #### Выше вы можете выборать самую лучшую модель "коробочку" по метрике F1
# #### Теперь вы знаете какой тип коробочки из представленных лучше всего работает на данной задаче
# #### Пора: 1) заново объявить эту коробочку
# #### 2) обучить на всем X,y
# #### 3) протестировать на отложенном X_valid, y_valid

# %%
tree.fit(X, y)
# Out:
# DecisionTreeClassifier(class_weight=None, criterion='gini', max_depth=None,
#             max_features=None, max_leaf_nodes=None,
#             min_impurity_decrease=0.0, min_impurity_split=None,
#             min_samples_leaf=1, min_samples_split=2,
#             min_weight_fraction_leaf=0.0, presort=False, random_state=None,
#             splitter='best')

# %%
# Взять лучшую модель и сделать предсказания для X_valid выборки
pred_final = tree.predict(X_valid)

# %%
# Посчитать метрики на полученном предсказании
print('accuracy_score: {}'.format(accuracy_score(y_valid, pred_final)))
print('precision_score: {}'.format(precision_score(y_valid, pred_final)))
print('recall_score: {}'.format(recall_score(y_valid, pred_final)))
print('f1_score: {}'.format(f1_score(y_valid, pred_final)))
# Out:
# accuracy_score: 0.7823608316566063
# precision_score: 0.14657210401891252
# recall_score: 0.17714285714285713
# f1_score: 0.16041397153945663
